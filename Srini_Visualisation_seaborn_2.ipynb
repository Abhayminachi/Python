# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
x = [-3,5,7]
y= [10,2,5]

# %%
# creating the plot
fig = plt.figure(figsize=(15,3))
plt.plot(x,y)
plt.xlabel('X axes')
plt.ylabel('Y axes')
plt.title('First plot')
plt.suptitle('Sub')
# Out:
# Text(0.5, 0.98, 'Sub')

# %%
#creating mulitple sub plots like 2 rows and 2 columns
ax = plt.subplots(2,2)

# %%
student = pd.read_csv("H:\\14_dataScience\\student.csv")
student.head()
# Out:
#    id        name  class  mark  gender  Age  height  weight State
# 0   1    John Deo   Four    75  female   18     165      50    KA
# 1   2    Max Ruin  Three    85    male   23     135      60    TN
# 2   3      Arnold  Three    55    male   18     138      73    KA
# 3   4  Krish Star   Four    60  female   25     129      58    KL
# 4   5   John Mike   Four    60  female   21     159      54    TN

# %%
student.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender', 'Age', 'height', 'weight',
#        'State'],
#       dtype='object')

# %%
# frequency table for two varibales
pd.crosstab(student.Age,student.State)
# Out:
# State  GA  KA  KL  MH  TN  TS
# Age
# 18      0   2   0   0   0   0
# 19      1   0   0   0   0   0
# 20      0   0   0   0   1   0
# 21      0   0   0   1   1   0
# 22      0   1   0   0   1   0
# 23      0   0   0   1   1   0
# 24      0   0   0   1   0   0
# 25      1   1   1   1   0   0
# 27      1   1   0   0   0   0
# 28      0   0   0   0   1   1
# 29      0   0   0   0   1   0
# 30      0   0   1   0   1   0
# 32      0   0   0   1   0   0
# 33      0   0   1   0   0   0
# 35      0   0   0   1   0   0
# 37      0   1   0   0   0   0
# 39      0   1   0   0   0   0
# 43      2   0   0   0   0   1
# 44      0   0   0   0   1   0
# 45      0   0   0   0   1   0
# 47      0   1   1   0   0   0
# 50      0   0   0   0   1   0

# %%
#Plotting the extracted table
pd.crosstab(student.State,student.Age).plot(kind = 'bar')
# Out:
# <Axes: xlabel='State'>

# %%
student["gender"].value_counts()
# Out:
# male      18
# female    17
# Name: gender, dtype: int64

# %%
student.State.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='State'>

# %%
plt.scatter(student.Age,student.weight)
plt.xlabel("Age")
plt.ylabel("weight")
plt.title("Data Plot")
plt.show()

# %%
plt.hist(student.Age,facecolor = 'yellow',edgecolor = 'red', bins=11,)
plt.xlabel("Age")
plt.ylabel("Freq")
plt.title("Data Plot")
plt.show()

# %%
plt.boxplot(student.weight)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209fb0fe9b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x209fb0feef0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x209fb0fe710>],
#  'medians': [<matplotlib.lines.Line2D at 0x209fb0ff430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209fb0ff6d0>],
#  'means': []}

# %%
plt.violinplot(student.Age)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x209fb1763b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x209fb176320>,
#  'cmins': <matplotlib.collections.LineCollection at 0x209fb0fc7c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x209fb176260>}

# %%
import seaborn as sns

# %%
sns.stripplot(y = student.Age,jitter=True)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.stripplot(x =student.State, y = student.height)
plt.ylabel('H')
# Out:
# Text(0, 0.5, 'H')

# %%
sns.swarmplot(x= student.gender,y= student.height,hue=student.State)
# Out:
# <Axes: xlabel='gender', ylabel='height'>

# %%
sns.boxplot(x = student.State, y = student.Age)
# Out:
# <Axes: xlabel='State', ylabel='Age'>

# %%
sns.violinplot(x = student.State,y= student.weight)
# Out:
# <Axes: xlabel='State', ylabel='weight'>

# %%
sns.stripplot(x =student.State, y = student.height)
sns.violinplot(x = student.State,y= student.height)
# Out:
# <Axes: xlabel='State', ylabel='height'>

# %%
sns.jointplot(x = student.State,y=student.Age)

# %%
#Full detailed plot including all the variables
sns.pairplot(student,hue = 'gender')

# %%
student.groupby('State')['gender'].count()
# Out:
# State
# GA     5
# KA     8
# KL     4
# MH     6
# TN    10
# TS     2
# Name: gender, dtype: int64

# %%
 ax = plt.subplots(figsize=(5,5))
sns.boxplot(x = student.State,y = student.Age,hue = student.gender)
# Out:
# <Axes: xlabel='State', ylabel='Age'>

# %%
sns.barplot(x =student.State,y= student.Age,hue = student.gender)
# Out:
# <Axes: xlabel='State', ylabel='Age'>

# %%
sns.distplot(student.Age)
# Out:
# C:\Users\Abhay Minachi\AppData\Local\Temp\ipykernel_12356\1280529182.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(student.Age)
# <Axes: xlabel='Age', ylabel='Density'>
