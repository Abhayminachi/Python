# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
x =  [-3,5,7]

# %%
y = [10,2,5]

# %%
fig = plt.figure(figsize=(15,3))
plt.plot(x,y)
plt.xlim(0,10)
plt.ylim(-3,8)
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('First plot')

# %%
ax= plt.subplots(nrows = 3,ncols=2)

# %%
df = pd.read_csv('Salary.csv')

# %%
df.tail(3)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#creates the frequency table of any two varibales having the numbers in them
pd.crosstab(df.salary,df.service)

# %%
pd.crosstab(df.salary,df.service).plot(kind="bar")

# %%
#value_counts() find the frequency of the data
df["phd"].value_counts().plot(kind="pie")

# %%
plt.scatter(df.phd,df.service)

# %%
plt.hist(df.phd,facecolor = 'red',edgecolor='blue',bins=4)

# %%
plt.boxplot(df.phd,vert=False)

# %% [markdown]
# # **Seaborn plots**

# %%
import seaborn as sns

# %%
#internal dataset it is
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#stripplot
sns.stripplot(y='tip',data=tips,jitter=True)
plt.ylabel('Tips$')
plt.show()

# %%
# gruping based on strip plot
sns.stripplot(x='day',y='tip',data=tips)
plt.ylabel('tips($)')
plt.show()

# %%
#swarm plot
sns.swarmplot(x='day',y='tip',data=tips)
plt.ylabel('tips')
plt.show()

# %%
#swarm plot
sns.swarmplot(x='day',y='tip',data=tips,hue='sex')
plt.ylabel('tips')
plt.show()

# %% [markdown]
# # ***Box and Violine plot***

# %%
sns.boxplot(x='day',y='tip',data=tips)
plt.ylabel('tips')
plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(x='day',y='tip',data=tips)
plt.subplot(1,2,2)
sns.violinplot(x='day',y='tip',data=tips)

# %%
sns.boxplot(x='day',y='tip',data=tips)
sns.stripplot(x='day',y='tip',data=tips)

# %%
#Joined two plots at a time
sns.jointplot(x='total_bill',y='tip',data = tips)

# %%
sns.jointplot(x='total_bill',y='tip',data = tips,kind='kde')

# %%
sns.pairplot(tips,hue='sex')

# %% [markdown]
# # Titanic data **visulaization** *italicized text*

# %%
print(tips.dtypes)

# %%
tips.groupby('day')['sex'].count()

# %%
ax = plt.subplots(figsize=(4,4))
sns.boxplot(x = 'day',y='total_bill',data=tips)
#sns.boxplot(x = 'sex',y='total_bill',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips)

# %%
sns.barplot(x='smoker',y='total_bill',data=tips)
